# %%
import pandas as pd

data = pd.read_excel('Gapminder.xlsx')

# %%
data
# Out:
#                    country  year  infant_mortality  life_expectancy  \
# 0                  Albania  1960            115.40            62.87
# 1                  Algeria  1960            148.20            47.50
# 2                   Angola  1960            208.00            35.98
# 3      Antigua and Barbuda  1960               NaN            62.97
# 4                Argentina  1960             59.87            65.39
# ...                    ...   ...               ...              ...
# 10540   West Bank and Gaza  2016               NaN            74.70
# 10541              Vietnam  2016               NaN            75.60
# 10542                Yemen  2016               NaN            64.92
# 10543               Zambia  2016               NaN            57.10
# 10544             Zimbabwe  2016               NaN            61.69
#
#        fertility  population           gdp continent              region
# 0           6.19   1636054.0           NaN    Europe     Southern Europe
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.shape
# Out:
# (10545, 9)

# %%
data.dtypes.to_frame()
# Out:
#                         0
# country            object
# year                int64
# infant_mortality  float64
# life_expectancy   float64
# fertility         float64
# population        float64
# gdp               float64
# continent          object
# region             object

# %%
data.head(2)
# Out:
#    country  year  infant_mortality  life_expectancy  fertility  population  \
# 0  Albania  1960             115.4            62.87       6.19   1636054.0
# 1  Algeria  1960             148.2            47.50       7.65  11124892.0
#
#             gdp continent           region
# 0           NaN    Europe  Southern Europe
# 1  1.382815e+10    Africa  Northern Africa

# %%
data.tail(2)
# Out:
#         country  year  infant_mortality  life_expectancy  fertility  \
# 10543    Zambia  2016               NaN            57.10        NaN
# 10544  Zimbabwe  2016               NaN            61.69        NaN
#
#        population  gdp continent          region
# 10543         NaN  NaN    Africa  Eastern Africa
# 10544         NaN  NaN    Africa  Eastern Africa

# %%
data1 = data.drop(columns=['infant_mortality', 'life_expectancy', 'fertility'])
data1.head(1)
# Out:
#    country  year  population  gdp continent           region
# 0  Albania  1960   1636054.0  NaN    Europe  Southern Europe

# %%
data2 = data.drop([0,2,4])
data2.head(1)
# Out:
#    country  year  infant_mortality  life_expectancy  fertility  population  \
# 1  Algeria  1960             148.2             47.5       7.65  11124892.0
#
#             gdp continent           region
# 1  1.382815e+10    Africa  Northern Africa
