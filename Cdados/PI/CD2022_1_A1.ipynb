# %% [markdown]
# ___
# # A1 - Avaliação de Ciência dos dados
#
# ## 2022 - 1o. semestre

# %% [markdown]
# Pedro Ivo Amaral Lima

# %% [markdown]
# ___
#
# **Leia atentamente as instruções desta avaliação. Essas devem ser seguidas rigorosamente!**
#
# **Prezado(a) Aluno(a),**
#
# Esta avaliação terá as seguintes etapas:
#
#  * **(10 minutos) - PROCTORIO:** Entre no Blackboard e inicie o teste em `Conteúdos/Avaliações/Avaliação (A1)/A1 (com Proctorio)`.
#
#  * **(90 minutos) - Desenvolvimento da prova:** Concentre-se em resolver o notebook.
#  * ATENÇÃO: administre esse tempo da maneira que julgar mais adequada para você. **NÃO utilize o cronômetro do Proctorio como referência, mas sim o tempo 90 minutos de prova.**
#
#  * **(10 minutos) - Entrega via Blackboard - Notebook:** O arquivo `.ipynb` deve ser entregue em `Conteúdos/Avaliações/Avaliação (A1)/Entrega da provuma`.
#  * ATENÇÃO: **finalize o proctorio (o teste) APENAS após anexar a avaliação no Blackboard.**
#
# <br>
#
# Leia atentamente as instruções a seguir e as questões da prova antes de começar a resolvê-la.

# %% [markdown]
# ___
# ### INSTRUÇÕES:
#
# Seguem instruções gerais enviadas no Blackboard:
#  * Data Início: link do teste estará disponível a partir do dia 03/03 (quinta) às 18h
#  * Data Fim: link do teste ficará disponível até dia 07/03 (segunda) às 22h
#  * Individual
#  * Proctorio: Ativado
#  * Duração: 1h30 min (cronômetro ativado)
#      * ATENÇÃO: Qualquer tempo a mais do que 90 minutos no cronômetro do teste, deve considerar como tempo extra para que possa salvar o arquivo notebook com a resolução da prova dentro do Blackboard ainda com o Proctorio aberto.
#  * Tentativa: uma única
#  * Assunto: até Análise Descritiva (até assunto da Aula 04)
#  * Material de consulta:
#   * **PERMITE consulta de material do Blackboard e material on-line (usar navegador para pesquisas no Google, por exemplo)**.
#   * **PERMITE UTILIZAR APENAS UM COMPUTADOR NO QUAL ESTARÁ REALIZANDO A PROVA.**
#   * **NÃO PERMITE consulta a colegas (presencial ou remotamente), ou seja, não é permitido ter alguém ao seu lado assim como não é permitido conversar pelo WhatsApp, enviar e-mail ou qualquer outro formato em que converse com outra pessoa**.
#   * **NÃO PERMITE utilizar CELULAR, TABLET, SEGUNDO COMPUTADOR (ou NOTEBOOK) ou qualquer outro aparelho eletrônico no momento da prova.**
#   * **Seu olhar deve estar sempre para tela do computador da prova. Evite olhar para baixo ou para os lados com frequência.**
#   * **A câmera deve estar bem centralizada ao seu rosto, sem filmar teto ou apenas parte do rosto para cima. Atenção em deixar a câmera regulada para dar prioridade em filmar seu rosto por inteiro em todo o momento da prova.**
#   * **O desrespeito as essas regras constituirá violação ao Código de Ética e de Conduta e acarretará sanções nele previstas. Faça o seu trabalho de maneira ética!**
#
#  * Questões: o enunciado de cada pergunta da prova estará EXCLUSIVAMENTE no teste do Blackboard
#  * Jupyter Notebook:
#      * será disponibilizado um notebook com as marcações de cada questão para construir o código/contas necessárias para resolvê-la
#      * salvar esse arquivo no HD do seu computador. NÃO salvar em OneDrive, Dropbox ou qualquer outro lugar fora do seu computador.
#  * Atenção: não compartilhe, por hipótese alguma, seu arquivo notebook da avaliação A1 enquanto o link do teste estiver disponível no Blackboard (ou seja, antes do dia 07/03 às 23h59)

# %% [markdown]
# **USO DA CÂMERA DO PROCTORIO**:
#
# **IMPORTANTE**: durante a prova, a sua câmera deve filmar da altura da sua cabeça para baixo priorizando mostrar mais o tronco do que o teto do local em que faz a prova. Caso a filmagem do seu Proctorio priorize mostrar, por qualquer período de tempo, apenas parte do seu rosto e/ou apenas do pescoço para cima e/ou você não aparecer na filmagem, isso será considerado violação do código de ética. Nesse caso, o MultiInsper será acionado para prestar possíveis esclarecimentos.

# %% [markdown]
# ## Avisos GERAIS:
#
# 1. Sua prova utilizará o sistema de Proctoring.  Para instalar a extensão, acesse o site https://getproctorio.com/ pelo Google Chrome e siga os passos indicados. Caso tenha dúvidas ou dificuldades, avise seu professor pelo chat e entre em contato com o Help Desk por meio de abertura de chamado ou pelo telefone (11) 4504-2550.
# Para realizar a prova será necessário:
#   *	Um desktop ou um notebook com qualquer sistema operacional (dispositivos móveis não serão aceitos)
#   *	Microfone (interno ou externo)
#   *	Webcam (interna ou externa)
#   *	Navegador Google Chrome (o sistema funciona somente nele)
#   *	Extensão da plataforma instalada (sem ela o sistema não funcionará)
#
# 1. **É proibido o uso de fones de ouvido durante toda a prova. Não leia as questões em voz alta. Não ouvir música.**
# 1. Sempre que possível, busque criar redundâncias para a rede de internet. Uma forma de fazer isso é utilizar a rede 4G dos celulares.
# 1. Antes de sair da prova, garanta que entregou a prova no link indicado. Verifique se arquivos das questões tiveram seu upload concluído (se necessário) e que fechou a prova ao final. Você é o responsável pela entrega adequada de todas as questões de sua prova. Avaliações entregues fora do prazo não serão aceitas para correção.
# 1. Caso precise se ausentar da frente da câmera para ia ao banheiro, comunique no chat do Teams ao professor e/ou fale para sua câmera. Dessa forma sua ausência estará justificada pelo sistema de proctoring. Lembre-se de ser rápido e retornar prontamente à prova.

# %% [markdown]
# ## Avisos sobre desenvolvimento da prova:
#
# 1. A prova contém 5 perguntas, sendo que a última é extra valendo 1,50 ponto. Caso sua nota nesta avaliação seja superior a 10, essa será truncada em 10 pontos.
# 1. Leia atentamente cada pergunta descrita no Blackboard e elabore o código no arquivo notebook acima citado para respondê-la. 1. O arquivo notebook deverá ser anexado ao Blackboard ao final da prova.
# 1. Será validada a construção do código para responder cada pergunta, entretanto, apenas a resposta corretamente no Blackboard fará jus a pontuação em cada item.
# 1. Leia atentamente as **Precauções de segurança** abaixo para evitar ter sua prova anulada.
# 1. Caso em algum item você necessite do resultado de um item anterior que você não conseguiu fazer, admita um valor razoável para esse resultado e faça o item normalmente. Indique na questão, caso isso aconteça.
# 1. Todos os resultados devem ser justificados. Números que apareçam sem uma explicação de como foram encontrados serão ignorados na correção.
# 1. **A qualidade do código na resolução em cada item também será levada em consideração, ou seja, códigos complicados para soluções que podem ser simples serão penalizados.**
# 1. Esta avaliação requer **entrega via Blackboard**. **Não serão consideradas entregas por outros meios** (ex: e-mail, MS Teams, etc.).

# %% [markdown]
# #### Precauções de segurança:
#
# 1.	Todas as precauções abaixo podem ser resumidas da seguinte forma: consulte o material que quiser desde que não seja nenhuma pessoa e não compartilhe informações com ninguém.
# 2.	Você não pode enviar nenhum tipo de mensagem durante a prova para qualquer pessoa dentro ou fora dela, com exceção do(a) professor(a). Por exemplo: e-mail, Skype, mensagens do Facebook, mensagens do WhatsApp, mensagens via Twitter, etc
# 3.	Você não pode compartilhar nenhum tipo de informação em nenhum site, incluindo Pastebin, Codeshare, wikis, etc
# 4.	Você não pode perguntar questões da prova no StackOverflow, StackExchange, MathExchange, etc.
# 5.	Você pode procurar/tirar dúvida no Google.
# 6.	Você pode consultar qualquer arquivo no seu computador.
# 7.	Qualquer transgressão das normas acima pode zerar a nota da prova e implicar em infração ao código de ética do Insper.

# %% [markdown]
# ___
# Carregando algumas bibliotecas:

# %%
# %matplotlib inline
import math
from math import sqrt

import os
import matplotlib.pyplot as plt
import numpy as np
from numpy import arange
import pandas as pd

from IPython.display import display  # Para ter melhor print.

# Pode trazer mais bibliotecas, caso julgue interessante!!

# %% [markdown]
# ___
# <div id="indice"></div>
#
# ## Índice
#
# - [PERGUNTA 1](#p1)
# - [PERGUNTA 2](#p2)
# - [PERGUNTA 3](#p3)
# - [PERGUNTA 4](#p4)
# - [PERGUNTA 5 - Extra](#p5)

# %% [markdown]
# <div id="abrindo-arquivo"></div>
#
# ___
#
# **Abrindo um arquivo de dados e visualizando seu conteúdo:**

# %%
print(f'Esperamos trabalhar no diretório: \n{os.getcwd()}\n')
# Out:
# Esperamos trabalhar no diretório:
# c:\Users\pedro\OneDrive\Documentos\GitHub\Semestre-2\Cdados\PI

# %%
filename = 'flavors_of_cacao.xlsx'

if filename in os.listdir():
    print(f'Parece que o arquivo {filename} está na mesma pasta do notebook, yay!')
    
else:
    print(f'Não encontrei o arquivo {filename}. Lembre-se que precisa estar na mesma pasta do arquivo notebook')
# Out:
# Parece que o arquivo flavors_of_cacao.xlsx está na mesma pasta do notebook, yay!

# %% [markdown]
# Abrindo a base de dados:

# %%
dados = pd.read_excel('flavors_of_cacao.xlsx')

# %% [markdown]
# Avaliando as 3 primeiras linhas da base de dados:

# %%
dados.head(3)
# Out:
#             Company BeanOriginOrBarName   REF  ReviewDate CocoaPercent  \
# 0  Chocolate Makers        Tres Hombres  1530        2015          75%
# 1  Chocolate Makers  Congo, Gorilla bar  1530        2015          68%
# 2  Chocolate Makers    Peru, Awagum bar  1530        2015          80%
#
#   CompanyLocation  Rating    BeanType     BroadBeanOrigin
# 0       Amsterdam    3.25  Trinitario  Dominican Republic
# 1       Amsterdam    3.50   Forastero               Congo
# 2       Amsterdam    3.75     Criollo                Peru

# %% [markdown]
# Avaliando o tipo de cada variável disponível no *dataframe* `dados`:

# %%
dados.dtypes
# Out:
# Company                 object
# BeanOriginOrBarName     object
# REF                      int64
# ReviewDate               int64
# CocoaPercent            object
# CompanyLocation         object
# Rating                 float64
# BeanType                object
# BroadBeanOrigin         object
# dtype: object

# %% [markdown]
# [Voltar ao Índice](#indice)

# %% [markdown]
# ___
# <div id="p1"></div>
#
# ### PERGUNTA 1 (1,40 pontos)
#
# **Leia o enunciado descrito no Blackboard para responder cada item a seguir:**

# %%
ano2006 = dados['ReviewDate'] == 2006
dados2006 = dados.loc[ano2006,:]
dados2006[['CocoaPercent']].value_counts()
# Out:
# CocoaPercent
# 75%             22
# 70%             13
# 65%              7
# 64%              5
# 72%              4
# 60%              2
# 61%              2
# 62%              2
# 66%              2
# 68%              2
# 71%              2
# 85%              1
# 82%              1
# 80%              1
# 100%             1
# 74%              1
# 73%              1
# 53%              1
# 67%              1
# 99%              1
# dtype: int64

# %%
dados2006[['CocoaPercent']].describe()
# Out:
#        CocoaPercent
# count            72
# unique           20
# top             75%
# freq             22

# %% [markdown]
# [Volta ao Índice](#indice)

# %% [markdown]
# ___
# <div id="p2"></div>
#
# ### PERGUNTA 2 (5,40 pontos)
#
# **Leia o enunciado descrito no Blackboard para responder cada item a seguir:**

# %%
ano2010 = dados['ReviewDate'] == 2010
dados2010 = dados.loc[ano2010,:]
dados2010.sort_values('Rating', ascending=False).head(3)

big3 = ['Spain', 'U.S.A.', 'Brazil']

# %%
b3 = dados['CompanyLocation'].isin(big3)
big3dados = dados.loc[b3, :]
big3dados
# Out:
#             Company                       BeanOriginOrBarName   REF  \
# 130     Q Chocolate                                    Brazil  1069
# 131     Q Chocolate                                    Brazil  1069
# 132     Q Chocolate                                    Brazil  1057
# 133     Q Chocolate                                    Brazil   935
# 134       De Mendes                            Nativo, Varzea  1462
# ...             ...                                       ...   ...
# 1758  Map Chocolate                                ROIG, 2014  1474
# 1759  Map Chocolate                             Maranon, 2014  1474
# 1760  Mast Brothers                        Chuao, Light Roast   713
# 1761  Map Chocolate                                   Ecuador  1478
# 1762  Map Chocolate  A case of the Xerces Blues, triple roast  1606
#
#       ReviewDate CocoaPercent CompanyLocation  Rating              BeanType  \
# 130         2013          80%          Brazil    3.25
# 131         2013          55%          Brazil    2.75
# 132         2013          85%          Brazil    3.50
# 133         2012          65%          Brazil    3.25
# 134         2015          72%          Brazil    3.50
# ...          ...          ...             ...     ...                   ...
# 1758        2015          70%          U.S.A.    3.50   Criollo, Trinitario
# 1759        2015          62%          U.S.A.    3.50  Forastero (Nacional)
# 1760        2011          81%          U.S.A.    2.75            Trinitario
# 1761        2015          70%          U.S.A.    3.50            Trinitario
# 1762        2015          70%          U.S.A.    3.50
#
#          BroadBeanOrigin
# 130               Brazil
# 131               Brazil
# 132               Brazil
# 133               Brazil
# 134               Brazil
# ...                  ...
# 1758  Dominican Republic
# 1759                Peru
# 1760           Venezuela
# 1761             Ecuador
# 1762           Nicaragua
#
# [806 rows x 9 columns]

# %%
big3dados[['Rating']].describe().round(4)
# Out:
#          Rating
# count  806.0000
# mean     3.1628
# std      0.4412
# min      1.5000
# 25%      2.7500
# 50%      3.2500
# 75%      3.5000
# max      4.0000

# %% [markdown]
# [Volta ao Índice](#indice)

# %% [markdown]
# ___
# <div id="p3"></div>
#
# ### PERGUNTA 3 (1,20 pontos)
#
# **Leia o enunciado descrito no Blackboard para responder cada item a seguir:**

# %%
dados

cros = pd.crosstab(dados['ReviewDate'], dados['Rating'])
cros
# cros.value_counts('ReviewDate')
# Out:
# Rating      1.00  1.50  1.75  2.00  2.25  2.50  2.75  3.00  3.25  3.50  3.75  \
# ReviewDate
# 2006           1     2     0    10     0     3     2    20     2    14     2
# 2007           2     1     0     4     0     8     2    23     3    15     7
# 2008           1     1     0     5     0    12    17    26     3    17     8
# 2009           0     1     1     4     0     6    23    42    14    16    12
# 2010           0     1     1     1     2     5    20    24    19    19    16
# 2011           0     2     0     2     1    10    22    23    29    38    23
# 2012           0     2     0     3     1    21    25    30    39    39    24
# 2013           0     0     1     0     3    15    30    27    41    36    18
# 2014           0     0     0     1     4    19    38    44    46    58    31
# 2015           0     0     0     1     2    12    40    47    61    80    34
# 2016           0     0     0     1     1    15    37    34    41    48    33
# 2017           0     0     0     0     0     1     3     1     5    12     2
#
# Rating      4.00  5.00
# ReviewDate
# 2006          15     1
# 2007          11     1
# 2008           3     0
# 2009           4     0
# 2010           3     0
# 2011          15     0
# 2012          11     0
# 2013          13     0
# 2014           6     0
# 2015           8     0
# 2016           9     0
# 2017           0     0

# %% [markdown]
# [Volta ao Índice](#indice)

# %% [markdown]
# ___
# <div id="p4"></div>
#
# ### PERGUNTA 4 (2,00 pontos)
#
# **Leia o enunciado descrito no Blackboard para responder cada item a seguir:**

# %%
# ESCREVA SEU CODIGO AQUI

# %%
dadoseq = dados.loc[dados['BroadBeanOrigin']=='Ecuador']
faixa = np.arange(1, 5.5, 0.5)
plt.hist(dados.Rating, bins=faixa, edgecolor='white', color='darkorange', density=True)
plt.show
dadoseq.describe()
# Out:
#                REF   ReviewDate      Rating
# count   193.000000   193.000000  193.000000
# mean    936.937824  2011.761658    3.134715
# std     595.543140     3.199150    0.527239
# min      40.000000  2006.000000    1.000000
# 25%     316.000000  2009.000000    2.750000
# 50%     979.000000  2012.000000    3.250000
# 75%    1454.000000  2015.000000    3.500000
# max    1944.000000  2017.000000    4.000000

# %% [markdown]
# [Volta ao Índice](#indice)

# %% [markdown]
# ___
# <div id="p5"></div>
#
# ### PERGUNTA 5 - EXTRA (1,50 pontos)
#
# **Leia o enunciado descrito no Blackboard para responder cada item a seguir:**

# %%
dados['CocoaPercentNum'] = dados['CocoaPercent'].replace('%', None )

dados
# Out:
#                Company    BeanOriginOrBarName   REF  ReviewDate CocoaPercent  \
# 0     Chocolate Makers           Tres Hombres  1530        2015          75%
# 1     Chocolate Makers     Congo, Gorilla bar  1530        2015          68%
# 2     Chocolate Makers       Peru, Awagum bar  1530        2015          80%
# 3         Metropolitan          South America  1688        2015          70%
# 4              Salgado         Bahia Superior   288        2008          70%
# ...                ...                    ...   ...         ...          ...
# 1790             Marou  Tien Giang, Gao Co-op   845        2012          70%
# 1791             Marou                Ben Tre   849        2012          78%
# 1792             Marou               Lam Dong   955        2012          74%
# 1793       Grand Place      Ben Tre, Dong Nai   741        2011          72%
# 1794       Baravelli's          single estate   955        2012          80%
#
#      CompanyLocation  Rating    BeanType     BroadBeanOrigin CocoaPercentNum
# 0          Amsterdam    3.25  Trinitario  Dominican Republic             75%
# 1          Amsterdam    3.50   Forastero               Congo             68%
# 2          Amsterdam    3.75     Criollo                Peru             80%
# 3          Amsterdam    3.50  Trinitario       South America             70%
# 4          Argentina    3.50   Forastero              Brazil             70%
# ...              ...     ...         ...                 ...             ...
# 1790         Vietnam    3.50  Trinitario             Vietnam             70%
# 1791         Vietnam    3.50  Trinitario             Vietnam             78%
# 1792         Vietnam    3.50  Trinitario             Vietnam             74%
# 1793         Vietnam    3.00  Trinitario             Vietnam             72%
# 1794           Wales    2.75                      Costa Rica             80%
#
# [1795 rows x 10 columns]

# %% [markdown]
# [Volta ao Índice](#indice)
